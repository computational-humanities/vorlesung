# %% [markdown]
# # Preliminaries

# %%
# %matplotlib notebook

# %%
from textblob import TextBlob
from textblob.taggers import NLTKTagger

from nltk.tokenize import SExprTokenizer
nltk_tagger = NLTKTagger()

import json
import pandas as pd
import re
    
import nltk.data
from nltk import PunktSentenceTokenizer

# %%
with open('secondVersion.json') as json_data:
    PoleisRawData = json.load(json_data)

# %% [markdown]
# # Structure of data

# %% [markdown]
# First level keys are the regions

# %%
PoleisRawData.keys()
# Out:
# dict_keys(['Crete', 'Sikelia', 'The Black Sea Area', 'The Aegean', 'Attika', 'Makedonia', 'Boiotia', 'Lykia', 'Spain and France (including Corsica)', 'Thrace from Axios to Strymon', 'Doris', 'Troas', 'Phokis', 'Inland Thrace', 'The Saronic Gulf', 'Epeiros', 'Aitolia', 'Lakedaimon', 'Italia and Kampania', 'Ionia', 'Achaia', 'Propontic Thrace', 'Akarnania and Adjacent Areas', 'Thracian Chersonesos', 'The Adriatic', 'Argolis', 'Elis', 'Lesbos', 'The Propontic Coast of Asia Minor', 'Triphylia', 'Thrace from Nestos to Hebros', 'Rhodos', 'Thessalia and Adjacent Regions', 'Arkadia', 'Messenia', 'West Lokris', 'East Lokris', 'Thrace from Strymon to Nestos', 'The South Coast of Asia Minor (Pamphylia Kilikia)', 'Cyprus', 'Euboia', 'Karia', 'Megaris, Korinthia, Sikyonia', 'Aiolis and South-western Mysia'])

# %% [markdown]
# Each region contains the city names as sub-keys

# %%
PoleisRawData['Karia'].keys()
# Out:
# dict_keys(['Ouranion', 'Kindye', 'Pedasa', 'Kyllandos', 'Taramptos', 'Kyrbissos', 'Pladasa', 'Chios', 'Olymos', 'Bargylia', 'Euromos', 'Pyrnos', 'Bargasa', 'Alabanda', 'Pyrindos', 'Pidasa', 'Amos', 'Tralleis', 'Kalynda', 'Aulai', 'Kaunos', 'Salmakis', 'Idrias', 'Knidos', 'Telemessos', 'Mylasa', 'Telandros', 'Naryandos', 'Chersonesos', 'Bolbai', 'Halikarnassos', 'Myndos', 'Lepsimandos', 'Medmasos', 'Passanda', 'Keramos', 'Kasolaba', 'Thydonos', 'Arlissos', 'Alinda', 'with', 'Hydisos', 'Iasos', 'Naxia'])

# %% [markdown]
# To access the text for a certain city, one has to use first and second level keys

# %%
hydisosText = PoleisRawData['Karia']['Hydisos']

# %%
hydisosText
# Out:
# 'Identifier: 891. , (Hydisseus) Map  61.  Lat. 37.10,long.  27.50. Size  of  territory:  ?  Type:  B:?  The  toponym  is  ` (Steph.  Byz. 645.17).  The  earliest  attestation  of  the  toponym is  in  a  C 1  inscription  (I.Stratonikeia 508.10  (c. 81)): `, although  it  was  mentioned  by  Apollonius  Aphrodisiensis, whose may  be  dated  to  C 3  (FGrHist 740  fr. 4).  The city-ethnic  is  `  (IG i³  265.ii.51;Apollonius Aphrodisiensis  (FGrHist 740)  fr. 4  (perhaps  C 3))  or `  (I.Mylasa 401.8  (C 2\xadC1)). Hydisos  was  a  member  of  the  Delian  League,  but  is  registered  only  twice,  in  448/7  (IG i³  264.iii.21,  restored: `[~]) and 447/6  (IG i³  265.ii.51,  restored: `[~]),  paying  a  phoros  of 1  tal. At  the  site  of  Hydisos  there  are  remains  of  city  walls  and towers,  probably  of  early  Hellenistic  date  (L.  Robert  ( 1935) 339\xad40). 890.  (Hymisseis) Map 61,  unlocated,  but  possibly  situat- ed  between  Amyzon  (no. 874)  and  Mylasa  (no. 913)  (Pontani ( 1997)  7;  cf.  L.  Robert  ( 1955)  226).  Type:  C: .  A  toponym  is not  attested.  The  city-ethnic  is  `µ  (IG i³  262.iv.19; restored:  [h ]µ~) or `µ  (IG i³  71.ii.143;  IG xii suppl. 127.58  (C 3)).  The  collective  use  of  the  city-ethnic  is attested  externally  in  the  tribute  lists  and  in  the  assessment decree  of 425/4  (IG i³  71.ii.143). The  Hymisseis  were  members  of  the  Delian  League.  They are  recorded  three  times  in  the  lists  from  451/0  (IG i³ 262.iv.19)  to  447/6  (IG i³  265.ii.50),  paying  a  phoros  of 1,200 dr.  In  the  assessment  decree  of 425/4  they  form  a  syntely  with the  Edrieis  (no. 892)  and  Kyromeis,  and  the  three  together are  assessed  at  6  tal.  (IG i³  71.ii.143\xad44).  A  Hymesseus  is recorded  in a C 3  list  of  proxenoi  from  Eresos  (no. 796)  (IG xii suppl. 127.58). 891. '

# %% [markdown]
# To generate a text of all cities in a region we can use

# %%
ioniaText = ''
for key in PoleisRawData['Ionia'].keys():
    ioniaText = ioniaText + (PoleisRawData['Ionia'][key])

# %% [markdown]
# # Create dataframe

# %% [markdown]
# To keep the original information, we create a dataframe with subindices: the region and the city name.

# %%
user_ids = []

frames = []

for user_id, d in PoleisRawData.items():
    user_ids.append(user_id)
    frames.append(pd.DataFrame.from_dict(d, orient='index'))

df = pd.concat(frames, keys=user_ids)
df.columns = ['fulltext']
df.index.rename(['region','city'], inplace=True)

# %% [markdown]
# ## Get city identifier
#
# Throughout the full text, cities are referenced by a running index. To make this information part of the dataframe, we extend it with an additional column.

# %%
def cityIDFinder(text):
    idList = re.findall("Identifier\: \d{1,4}\.", text)
    if idList: 
        idCity = idList[0].split('.')[0][12:]
        return idCity

# %%
df['city_id'] = df['fulltext'].apply(lambda row: cityIDFinder(row))

# %% [markdown]
# ## Collection of all citations
#
# To collect all citations in the text for one city, we first use a tokenizer from NLTK. This tokenizer collects all parenthesis and is much easier to use, that regular expressions.
#
# The basic assumption for citations is: They are written in parenthesis, start with a capital letter, and contain at least one blank space (to separate the authors name from text pages, indices, or dates).

# %%
def citationFinder(text):
    import string
    letters=[i for i in string.ascii_uppercase] # List of all capital letters
    paranthesisTokenized = SExprTokenizer(strict=False).tokenize(text) # Tokenize text to search for parenthesis, '( ... )'  
    listCite = [x for x in paranthesisTokenized if x[0] == '(' and x[1] in letters and ' ' in x] # Assume: Citations are in parenthesis, start with a capital letter, and contain at least one blank space ' '
    return listCite

# %%
df['sources'] = df['fulltext'].apply(lambda row: citationFinder(row))

# %% [markdown]
# ## Transformation of coordinates
#
# A simple regular expression is enough to find all coordinates in the text. The coordinates are transformed from degrees/minutes to decimal to enable plotting on a map with common projection.

# %%
def coordinateFinder(value,pattern):
    x = re.findall(pattern, value)
    if x:
        coord = x[0][-5:]
        decCord = float(coord.split('.')[0]) +  int(coord.split('.')[-1])/60
        return decCord

# %%
df['latitude'] = df["fulltext"].apply(coordinateFinder, pattern="Lat\.\s?\d+\.\d+")
df['longitude'] = df["fulltext"].apply(coordinateFinder, pattern="long\.\s*\d+\.\d+")

# %% [markdown]
# ## Proper nouns
#
# To generate a list of all mentioned proper nouns for each city, we use TextBlob. TextBlob is a NLTK tool with parts-of-speech tagger. We are interessted in all parts that are 'NNP' and longer then 3 letters.
#
# This takes some time to process for the full dataframe. Behaviour can be tested by uncommenting the cell below.

# %%
# Uncomment to test routine. 

#namesFinder(df['fulltext'].iloc[10])

# %%
def namesFinder(text):
    blobs = TextBlob(text)
    namesList = [x[0] for x in blobs.pos_tags if x[1] == 'NNP' and len(x[0]) > 3]
    return namesList

# %%
df['names'] = df['fulltext'].apply(lambda row: namesFinder(row))

# %% [markdown]
# ## Cross links to other cities
#
# Links to other cities are mentioned in the fulltext with reference to the index (e.g. '(no. 982)'). searching for these should give a link list.

# %%
def linksFinder(text):
    x = re.findall("\(no\. \d{1,4}\)", text)
    if x:
        links = [((z.split(' '))[-1])[:-1] for z in x]
        linksInt = [int(x) for x in links]
        return linksInt

# %%
df['linkedCities'] = df['fulltext'].apply(lambda row: linksFinder(row))

# %% [markdown]
# ## Display dataframe

# %%
# Uncomment to display full dataframe

df
# Out:
#                                                                                        fulltext  \
# region                         city
# Crete                          Hierapytna     Identifier: 963. , (Hierapytnios) Map  60.Lat....
#                                Eleutherna     Identifier: 959. , (Eleuthernaios) Map  60.Lat...
#                                Stalai         Identifier: 990. , (Stalites) Map  60.  Lat. 3...
#                                Aulon          Identifier: 952. , Map 60.  Lat. 35.05,long.  ...
#                                Herakleion     Identifier: 962. , (Herakleiotas) Map  60.  La...
#                                Lisos          Identifier: 5 , (Lisios) Map  60.  Lat. 35.15,...
#                                Keraia         Identifier: 967. , (Keraïtas) Map  60.Lat.35.2...
#                                Aptara         Identifier: 948. , (Aptaraios) Map  60.  Lat. ...
#                                Rhaukos        Identifier: 987. , (Rhaukios) Map  60.  Lat. 3...
#                                Itanos         Identifier: 966. , (Itanios) Map  60.Lat.35.15...
#                                Phaistos       Identifier: 981. , (Phaistios) Map. 60.  Lat. ...
#                                Apellonia      Identifier: 947. , (Apelloniatas) Map  60.  La...
#                                Phalasarna     Identifier: 982. , (Phalasarnios) Map  60.  La...
#                                Datala         Identifier: 955. , (Datales) Map  60.  Unlocat...
#                                Sybrita        Identifier: 991. , (Sybritios) Map  60.  Lat. ...
#                                Hyrtakina      Identifier: 965. , (Hyrtakinios) Map  60.  Lat...
#                                Olous          Identifier: 980. , (Olontios) Map  60.  Lat. 3...
#                                Priansos       Identifier: 986. , (Priansieus) Map. 60.  Lat....
#                                Allaria        Identifier: 945. , (Allariotas) Map  60.  Lat....
#                                Dreros         Identifier: 957. , (Drerios) Map  60.  Lat. 35...
#                                Arkades        Identifier: 949. , (Arkas) Map  60.  Lat. 35.0...
#                                Lappa          Identifier: 973. , (Lappaios) Map  60.  Lat. 3...
#                                Anopolis       Identifier: 946. , (Anopolites)  Map  60.  Lat...
#                                Tarrha         Identifier: 992. , (Tarrhaios) Map  60.  Lat. ...
#                                Praisos        Identifier: 985. , (Praisios) Map  60.  Lat. 3...
#                                Rhithymnos     Identifier: 989. , (Rhithymnios)  Map  60.  La...
#                                Malla          Identifier: 976. , (Mallaios) Map  60.  Lat. 3...
#                                Kytaion        Identifier: 970. , Map 60.  Lat. 35.25,long.  ...
#                                Milatos        Identifier: 978. , (Milatios) Map  59.  Lat. 3...
#                                Matala         Identifier: 977. , (Matalios) Map. 60.  Lat. 3...
# ...                                                                                         ...
# Karia                          Iasos          Identifier: 892. , (Iaseus) Map  61.  Lat. 37....
#                                Naxia          Identifier: 919. , (Naxiates) Map  61.  Lat. 3...
# Megaris, Korinthia, Sikyonia   Megara         Identifier: 226. , (Megareus) Map  58.  Lat. 3...
#                                Aigosthena     Identifier: 225. , (Aigosthenitas)  Map  58.  ...
# Aiolis and South-western Mysia Larisa         Identifier: 819. , (Larisaios) Map  56.  Lat. ...
#                                Palaigambrion  Identifier: 828. , Unlocated,  not  in  Barr. ...
#                                Temnos         Identifier: 833. , (Temnites) Map  56.  Lat. 3...
#                                Karene         Identifier: 815. , (Karenaios) Map  56.  Lat. ...
#                                Chalkis        Identifier: 807. , (Chalkideus)  Map  56.  Lat...
#                                Halisarna      Identifier: 5 , Map 56.  Lat. 39.05,long.  27....
#                                Magnesia       Identifier: 822. , (Magnes) Map  56.  Lat. 38....
#                                Gambrion       Identifier: 98, (Gambreiotes) Map  56.  Lat. 3...
#                                Adramyttion    Identifier: 801. , (Adramytenos) Map  56.  Lat...
#                                Thebe          Identifier: 1051, Map 56.Lat.39.35,long.27.00,...
#                                Aigiroessa     Identifier: 803. , Unlocated.  Type:  A: .  Th...
#                                Kisthene       Identifier: 818. , Map 56.Lat.39.25,long.26.50...
#                                Gryneion       Identifier: 810. , is  one  of  the  toponyms ...
#                                Atarneus       Identifier: 804. , (Artaneites)  Map  56.  Lat...
#                                Notion         Identifier: 826. , Unlocated.  Type  A: .The t...
#                                Myrina         Identifier: 823. , (Myrinaios) Map  56.  Lat. ...
#                                Kyme           Identifier: 813. , is  noted  by  Mørkholm  ( ...
#                                Pitane         Identifier: 832. , (Pitanaios) Map  56.  Lat. ...
#                                Autokane       Identifier: 806. , (Autokanaios?) Unlocated,  ...
#                                Pergamon       Identifier: 15., (Pergamenos) Map  56.  Lat. 3...
#                                Leukai         Identifier: 820. , (Leokates) Map  56.Lat.38.3...
#                                Teuthrania     Identifier: 834. , Map 56.  Lat. 39.00,long.  ...
#                                Nasos          Identifier: 825. , (Nasiotas) Map  56.  Lat. 3...
#                                Aigai(ai)      Identifier: 802. , (Aigaieus) Map  56.  Lat. 3...
#                                Perperene      Identifier: 830. , was  probably  located  1  ...
#                                Elaia          Identifier: 808. , (Elaiites) Map  56.  Lat. 3...
#
#                                                latitude  longitude  \
# region                         city
# Crete                          Hierapytna     35.000000  25.750000
#                                Eleutherna     35.333333  24.666667
#                                Stalai         35.083333  26.000000
#                                Aulon          35.083333  25.000000
#                                Herakleion     35.333333  25.166667
#                                Lisos          35.250000  23.833333
#                                Keraia         35.416667  24.000000
#                                Aptara         35.416667  24.166667
#                                Rhaukos        35.250000  25.000000
#                                Itanos         35.250000  26.250000
#                                Phaistos       35.083333  24.833333
#                                Apellonia      35.416667  25.000000
#                                Phalasarna     35.500000  23.583333
#                                Datala               NaN        NaN
#                                Sybrita        35.250000  24.666667
#                                Hyrtakina      35.250000  23.750000
#                                Olous          35.250000  25.750000
#                                Priansos       35.083333  25.250000
#                                Allaria        35.416667  24.583333
#                                Dreros         35.250000  25.666667
#                                Arkades        35.083333  25.333333
#                                Lappa          35.250000  24.333333
#                                Anopolis       35.250000  24.083333
#                                Tarrha         35.250000  24.000000
#                                Praisos        35.166667  26.083333
#                                Rhithymnos     35.333333  24.500000
#                                Malla          35.083333  25.583333
#                                Kytaion        35.416667  24.916667
#                                Milatos        35.333333  25.583333
#                                Matala         35.000000  24.750000
# ...                                                 ...        ...
# Karia                          Iasos          37.250000  27.583333
#                                Naxia          37.583333  27.666667
# Megaris, Korinthia, Sikyonia   Megara         38.000000        NaN
#                                Aigosthena     38.166667  23.250000
# Aiolis and South-western Mysia Larisa         38.666667  27.000000
#                                Palaigambrion  39.250000  27.333333
#                                Temnos         38.666667  27.166667
#                                Karene         39.166667  26.833333
#                                Chalkis        39.250000  26.583333
#                                Halisarna      39.083333  27.083333
#                                Magnesia       38.583333  27.416667
#                                Gambrion       39.083333  27.333333
#                                Adramyttion    39.500000  26.916667
#                                Thebe          39.583333  27.000000
#                                Aigiroessa           NaN        NaN
#                                Kisthene       39.416667  26.833333
#                                Gryneion             NaN        NaN
#                                Atarneus       39.083333  26.916667
#                                Notion               NaN        NaN
#                                Myrina         38.833333  27.000000
#                                Kyme                 NaN        NaN
#                                Pitane         38.916667  26.916667
#                                Autokane       39.000000  26.833333
#                                Pergamon       39.166667  27.166667
#                                Leukai         38.583333  26.833333
#                                Teuthrania     39.000000  27.083333
#                                Nasos          39.333333  26.666667
#                                Aigai(ai)      38.833333  27.166667
#                                Perperene            NaN        NaN
#                                Elaia          38.916667  27.083333
#
#                                                                                         sources  \
# region                         city
# Crete                          Hierapytna     [(I.Cret. iii.iii.1B  (C 3l);  IG xii.5840  (C...
#                                Eleutherna     [(IG ix².117,ll.  87­88  (C 3f)), (SEG 41  742...
#                                Stalai         [(Steph.  Byz. 585.12), (I.Cret.iii.vi.7  (C 3...
#                                Aulon          [(I.Cret. iv  64  (C 5e)), (Steph.  Byz. 147.8...
#                                Herakleion     [(Hellenistic  period), (Strabo  10.4.7), (Mil...
#                                Lisos          [(I.Cret. ii.xvii.1 (C 3f);  BCH 45  ( 1921)  ...
#                                Keraia         [(BCH 45 ( 1921)  iii.111  (c. 230­210)), (I.M...
#                                Aptara         [(SEG 41  731  (C 3e)), (BCH 45  ( 1921)  iii....
#                                Rhaukos        [(Ps.- Skylax 47;Polyb.  30.23.1), (I.Cret. i....
#                                Itanos         [(Hdt. 4.151.2), (I.Cret. iii.vii.3  (C 6?); c...
#                                Phaistos       [(Hom.  Il. 2.648;  Ps.-Skylax 47;  Milet. i.3...
#                                Apellonia      [(Alexiou  ( 1984);  cf.  Faure  ( 1963) 16­17...
#                                Phalasarna     [(Ps.-Skylax  47;  BCH 45  ( 1921)  iii.102 (c...
#                                Datala         [(I.Cret.  i.xvi.5,l.  64  (C 2l)), (Chaniotis...
#                                Sybrita        [(Ps.- Skylax 47), (Scafa  ( 1994)), (BCH 45  ...
#                                Hyrtakina      [(Ps.-Skylax  47), (Steph.  Byz. 652.20), (Ste...
#                                Olous          [(Ps.-Skylax 47;  I.Cret. i.xvi.3.3  (C 2)), (...
#                                Priansos       [(I.Cret. iv  174  (C 3l/C2e)), (I.Cret. iii.i...
#                                Allaria        [(IG xii.3328  (C 3f)), (I.Cret. ii.i.1  (from...
#                                Dreros         [(BCH 60  ( 1936)  280­85  (C 4/C3)), (I.Cret....
#                                Arkades        [(I.Cret. iv  171  (C 3m);  BCH 45  ( 1921)  i...
#                                Lappa          [(BCH 45  ( 1921)  iii.115  (c. 230­210);  I.C...
#                                Anopolis       [(BCH 45  ( 1921)  iii.109  (c. 230­210);  SEG...
#                                Tarrha         [(BCH 45 ( 1921)  iii.107  (c. 230­210)), (I.C...
#                                Praisos        [(I.Cret. iii.iv.1  (C 3e)), (I.Cret. iii.iv.1...
#                                Rhithymnos     [(Arkesine,  IG xii.77A.3  (C 4l­C3e)), (Delph...
#                                Malla          [(I.Cret. i.xix.1  (C 3m)), (I.Cret. i.xix.1 (...
#                                Kytaion        [(Ptol.  Geog. 3.17.6;  Steph.  Byz. 399.3), (...
#                                Milatos        [(BCH 70  ( 1946)  588­90  no. 1  (C 6e);  I.C...
#                                Matala         [(BCH 45  ( 1921)  iv.14  (c. 230­210);  Stadi...
# ...                                                                                         ...
# Karia                          Iasos          [(Thuc. 8.28.2;  Archestratos  fr. 26.1,  Olso...
#                                Naxia          [(IG i³  267.iii.29), (IG i³ 261.v.8), (IG i³ ...
# Megaris, Korinthia, Sikyonia   Megara         [(IG i³  1353  (C 5s);Hdt.9.14), (Hdt.9.21.1; ...
#                                Aigosthena     [(Xen.  Hell. 5.4.18), (IG vii  1.5  (c. 300);...
# Aiolis and South-western Mysia Larisa         [(Hdt. 1.149.1), (Xen.  Hell. 3.1.7), (Strabo ...
#                                Palaigambrion      [(Xen.  Hell. 3.1.6), (Xen. An. 7.8.15,  23)]
#                                Temnos         [(Hdt. 1.149.1), (Suda 3024,  conjectured  at ...
#                                Karene         [(Hdt. 7.42), (Krateros (FGrHist 342)  fr. 2),...
#                                Chalkis                  [(Stauber  ( 1996a)  i. 228), (C 5/C4)]
#                                Halisarna              [(Xen.  Hell. 3.1.6;  An. 7.8.17), (C 5)]
#                                Magnesia       [(Hellan.  fr. 191), (Ihnken  ( 1978)  160  T ...
#                                Gambrion       [(Xen.  Hell. 3.1.6), (Syll. ³ 1219.4  Michel ...
#                                Adramyttion    [(Hdt. 7.42.1;Xen.  An. 7.8.8;  Kratinos  fr. ...
#                                Thebe          [(Dikaiarchos  fr. 53a,  Wehrli), (Hom.  Il. 1...
#                                Aigiroessa                  [(Hdt. 1.149.1), (Head,  HN ²  554)]
#                                Kisthene       [(Isoc. 4.153), (Stauber  ( 1996a)  ii. 261­64...
#                                Gryneion       [(SNG  Cop.  Aiolis 202­7), (IG i³  265.i.17),...
#                                Atarneus       [(Hdt. 6.28.2,  8.106.1;  Arist.  Pol. 1267a32...
#                                Notion                                          [(Hdt. 1.149.1)]
#                                Myrina         [(Hdt. 1.149.1;Xen.  Hell. 3.1.6), (SNG  Cop. ...
#                                Kyme                  [(Stauber  ( 1996a) ii. 248­49  nos. 1­8)]
#                                Pitane         [(Hdt. 1.149.1), (IG i³ 262.iii.24;  Krateros ...
#                                Autokane       [(Hymn.  Hom.  Ap. 35), (IG ix.2  1105a), (Sch...
#                                Pergamon       [(Xen.  Hell. 3.1.6;  An. 7.8.8,  23), (IAEpid...
#                                Leukai         [(Ps.- Skylax 98;Strabo 14.1.38), (Diod. 15.18...
#                                Teuthrania     [(Hdt. 2.10.1), (Ps.-Skylax  98;Xen.Hell.3.1.6...
#                                Nasos          [(I.Adramytteion 34A.40  (C 4l)), (I.Adramytte...
#                                Aigai(ai)      [(Hdt. 1.149.1), (Ps.-Skylax  98;Strabo 13.3.5...
#                                Perperene      [(Stauber  ( 1996a)  ii. 309­25,  cat.  nos. 1...
#                                Elaia          [(IG i³  268.ii.28;  Ps.-Skylax 98;Polyb.  21....
#
#                                              city_id  \
# region                         city
# Crete                          Hierapytna        963
#                                Eleutherna        959
#                                Stalai            990
#                                Aulon             952
#                                Herakleion        962
#                                Lisos            None
#                                Keraia            967
#                                Aptara            948
#                                Rhaukos           987
#                                Itanos            966
#                                Phaistos          981
#                                Apellonia         947
#                                Phalasarna        982
#                                Datala            955
#                                Sybrita           991
#                                Hyrtakina         965
#                                Olous             980
#                                Priansos          986
#                                Allaria           945
#                                Dreros            957
#                                Arkades           949
#                                Lappa             973
#                                Anopolis          946
#                                Tarrha            992
#                                Praisos           985
#                                Rhithymnos        989
#                                Malla             976
#                                Kytaion           970
#                                Milatos           978
#                                Matala            977
# ...                                              ...
# Karia                          Iasos             892
#                                Naxia             919
# Megaris, Korinthia, Sikyonia   Megara            226
#                                Aigosthena        225
# Aiolis and South-western Mysia Larisa            819
#                                Palaigambrion     828
#                                Temnos            833
#                                Karene            815
#                                Chalkis           807
#                                Halisarna        None
#                                Magnesia          822
#                                Gambrion         None
#                                Adramyttion       801
#                                Thebe            None
#                                Aigiroessa        803
#                                Kisthene          818
#                                Gryneion          810
#                                Atarneus          804
#                                Notion            826
#                                Myrina            823
#                                Kyme              813
#                                Pitane            832
#                                Autokane          806
#                                Pergamon           15
#                                Leukai            820
#                                Teuthrania        834
#                                Nasos             825
#                                Aigai(ai)         802
#                                Perperene         830
#                                Elaia             808
#
#                                                                                    linkedCities  \
# region                         city
# Crete                          Hierapytna                        [971, 958, 974, 950, 954, 962]
#                                Eleutherna                                                  None
#                                Stalai                                                      None
#                                Aulon                                                       None
#                                Herakleion                                                  None
#                                Lisos                                                       None
#                                Keraia                                                      None
#                                Aptara                                                      None
#                                Rhaukos                                          [960, 980, 971]
#                                Itanos                                                      None
#                                Phaistos                                    [960, 976, 952, 960]
#                                Apellonia                                                   None
#                                Phalasarna                                                  None
#                                Datala                                                      None
#                                Sybrita                                                     None
#                                Hyrtakina                                                  [971]
#                                Olous                                                       None
#                                Priansos                                                   [960]
#                                Allaria                                                     None
#                                Dreros                                                      None
#                                Arkades                                                     None
#                                Lappa                                                       None
#                                Anopolis                                                    None
#                                Tarrha                                                      None
#                                Praisos                                                     None
#                                Rhithymnos                                                  None
#                                Malla                                                       None
#                                Kytaion                                                     None
#                                Milatos                                                     None
#                                Matala                                                      None
# ...                                                                                         ...
# Karia                          Iasos             [674, 844, 903, 747, 748, 1000, 864, 913, 902]
#                                Naxia                                                       None
# Megaris, Korinthia, Sikyonia   Megara         [227, 224, 226, 345, 227, 361, 347, 361, 177, ...
#                                Aigosthena                                                  None
# Aiolis and South-western Mysia Larisa                                                      None
#                                Palaigambrion                                               None
#                                Temnos                                                      None
#                                Karene                                                      None
#                                Chalkis                                                    [823]
#                                Halisarna                                                   None
#                                Magnesia                                                    None
#                                Gambrion                                                    None
#                                Adramyttion                                                 None
#                                Thebe                                                       None
#                                Aigiroessa                                                  None
#                                Kisthene                                                    None
#                                Gryneion                                                    None
#                                Atarneus                                                    None
#                                Notion                                                      None
#                                Myrina                                                      None
#                                Kyme                                                        None
#                                Pitane                                                      None
#                                Autokane                                                    None
#                                Pergamon                                                    None
#                                Leukai                                                      None
#                                Teuthrania                                                  None
#                                Nasos                                                      [798]
#                                Aigai(ai)                                                   None
#                                Perperene                                                   None
#                                Elaia                                                       None
#
#                                                                                           names
# region                         city
# Crete                          Hierapytna     [Hierapytnios, I.Cret, xii.5840, Steph, I.Cret...
#                                Eleutherna     [Eleuthernaios, I.Cret, Skylax, Stephanos, Ste...
#                                Stalai         [Stalites, Steph, I.Cret.iii.vi.7, I.Cret.iii....
#                                Aulon          [I.Cret, Steph, Stephanos, Aulon, Guarducci, A...
#                                Herakleion     [Herakleiotas, Hellenistic, Strabo, Milet, Her...
#                                Lisos          [Lisios, I.Cret, Ps.-Skylax, Guarducci, Svoron...
#                                Keraia         [Keraïtas, Polyb, Steph, Keraia, Polyb, I.Magn...
#                                Aptara         [Aptaraios, B.The, The-city, I.Cret, I.Cret, S...
#                                Rhaukos        [Rhaukios, Ps.-, Skylax, Polyb, Milet, Rhaukos...
#                                Itanos         [Itanios, I.Cret, Itanos, Herodotos, Kyrene, T...
#                                Phaistos       [Phaistios, Milet, Linear, McArthur, Rider, Ph...
#                                Apellonia      [Apelloniatas, Pelagia, Crete, Herakleion, Ale...
#                                Phalasarna     [Phalasarnios, I.Cret, Phalasarna, Phalasarna,...
#                                Datala         [Datales, I.Cret, Kydonia, Chaniotis, Archaic,...
#                                Sybrita        [Sybritios, Ps.-, Skylax, Linear, Scafa, Guard...
#                                Hyrtakina      [Hyrtakinios, Steph, Steph, I.Cret, Milet, Ps....
#                                Olous          [Olontios, I.Cret, I.Cret, I.Cret, Crete, Bile...
#                                Priansos       [Priansieus, I.Cret, I.Cret, I.Cret, Cretan, D...
#                                Allaria        [Allariotas, xii.3328, I.Cret, Teos, Polyb, Al...
#                                Dreros         [Drerios, Dreros, Archaic, Nomima, Nomima, Arc...
#                                Arkades        [Arkas, I.Cret, Skepsis, Steph, Theophr, Sen.,...
#                                Lappa          [Lappaios, I.Cret, Guarducci, I.Cret, Lappa, L...
#                                Anopolis       [Lappa, I.Cret, Anopolis, Araden, Steph, Anopo...
#                                Tarrha         [Tarrhaios, I.Cret, Tarrha, Paus, Steph, Helle...
#                                Praisos        [Praisios, I.Cret, I.Cret, Guarducci, Ps.-Skyl...
#                                Rhithymnos     [Rhithymnios, Crete, Arkesine, xii.77A.3, Delp...
#                                Malla          [Mallaios, I.Cret, I.Cret, Malla, Malla, Malla...
#                                Kytaion        [Ptol, Geog, Steph, Kytaion, Kytaion, Apelloni...
#                                Milatos        [Milatios, Doric, Hom.Il.2.647, Ephor.fr.127, ...
#                                Matala         [Matalios, Stadiasmus, Strabo, Milet, Matala, ...
# ...                                                                                         ...
# Karia                          Iasos          [Iaseus, Thuc, Archestratos, Olson, Sens, I.Ia...
#                                Naxia          [Naxiates, Meritt, Robert, Miletos, Myous, Nax...
# Megaris, Korinthia, Sikyonia   Megara         [Megareus, A.The, Hdt.9.14, .The, Hdt.9.21.1, ...
#                                Aigosthena     [Aigosthenitas, Hell, Aigosthena, Megara, Hell...
# Aiolis and South-western Mysia Larisa         [Larisaios, Hell, Larisa, Strabo, Xen.Hell.3.1...
#                                Palaigambrion  [Barr, Hell, Hell, Thibron, Gongylos, Eretria,...
#                                Temnos         [Suda, Strabo, Strabo, Aiolic, I.Perg, Aiolian...
#                                Karene         [Karenaios, Krateros, FGrHist, Stauber, Ilias,...
#                                Chalkis        [Chalkideus, Chalkis, Çiplakada, Steph, Chalki...
#                                Halisarna      [Hell, Halisarna, Hell, Thibron, Halisarna, Pr...
#                                Magnesia       [Hellan, Abydos, Ihnken, Jeffery, Ihnken, Jeff...
#                                Gambrion       [Gambreiotes, Hell, Syll, Michel, LSAM, Hell, ...
#                                Adramyttion    [Adramytenos, Kratinos, Thuc, Fossey, Herodoto...
#                                Thebe          [Stauber, Küçük, Tepe, Dikaiarchos, Wehrli, Sa...
#                                Aigiroessa     [Herodotos, Stein, Aigiroessa, Elaia, Herodoto...
#                                Kisthene       [Isoc, Kisthene, Gömeç, Stauber, Isoc, Kisthen...
#                                Gryneion       [Iscr, Iscr, Aiolis, Gryneion, Gongylos, Hell,...
#                                Atarneus       [Arist, Isoc, Hell, Theopomp, I.Erythrai, Klaz...
#                                Notion             [Aiolian, Notion, Notion, Kolophon, Hoepfner]
#                                Myrina         [Myrinaios, Hell, IGi³71.i.179­80, Aiolian, My...
#                                Kyme           [Mørkholm, Iolleus, Adramyttion, Size, Iolla, ...
#                                Pitane         [Pitanaios, Krateros, FGrHist, Steph, Aiolian,...
#                                Autokane       [Autokanaios, Kane, Hymn, Homeric, Hymn, Aioli...
#                                Pergamon       [Pergamenos, Hell, Staatsverträge555, Hell, Th...
#                                Leukai         [Leokates, Ps.-, Skylax, Strabo, Diod, Babelon...
#                                Teuthrania     [Xen.Hell.3.1.6, Teuthrania, Hell, Thibron, Te...
#                                Nasos          [Nasiotas, Aiolic, I.Adramytteion, Hekatonneso...
#                                Aigai(ai)      [Aigaieus, Strabo, Hell, Michel, Head, Head, P...
#                                Perperene      [žsagibey, Kaufmann, Stauber, Stauber, Archaic...
#                                Elaia          [Polyb, I.Délos, Paus, Chios, Steph, Ps.-, Sky...
#
# [598 rows x 7 columns]

# %% [markdown]
# # Mapping the cities
#
# To generate a map with the newly found informations, we use folium. Markers are positioned at (lat/long) and give the city index, i.e. its name, after clicking on the blue marker.
# Note, that cities without coordinates are dropped from the dataframe.

# %%
import folium
from folium import plugins
from folium.map import *

dfPoleisMap = df.dropna(axis=0)

# %%
poleis_map = folium.Map(location=[dfPoleisMap["latitude"][0],dfPoleisMap["longitude"][0]], zoom_start=8)

marker = FeatureGroup(name='Poleis')
marker_cluster = folium.MarkerCluster().add_to(marker)

for i in range(len(dfPoleisMap)):
    folium.Marker([dfPoleisMap['latitude'][i], dfPoleisMap['longitude'][i]],popup='Cityname:' + str(dfPoleisMap.index.get_level_values(1)[i]),icon=folium.Icon(icon='ok')).add_to(marker_cluster)
                  
poleis_map.add_children(marker)

poleis_map.add_children(folium.map.LayerControl())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# # Training of Tokenizers
#
# By calling PunktSentenceTokenizer with an input text, we can train the detection of sentences. This is usually a problem, since a lot of citations (parenthesis) or special characters hinder the detection of a sentence end.

# %%
trainedTokenizer = PunktSentenceTokenizer(ioniaText)

# %%
for item in trainedTokenizer.tokenize(hydisosText):
    print(item)
    print("----")
# Out:
# Identifier: 891. , (Hydisseus) Map  61.  Lat. 37.10,long.
# ----
# 27.50. Size  of  territory:  ?
# ----
# Type:  B:?
# ----
# The  toponym  is  ` (Steph.
# ----
# Byz. 645.17).
# ----
# The  earliest  attestation  of  the  toponym is  in  a  C 1  inscription  (I.Stratonikeia 508.10  (c. 81)): `, although  it  was  mentioned  by  Apollonius  Aphrodisiensis, whose may  be  dated  to  C 3  (FGrHist 740  fr. 4).
# ----
# The city-ethnic  is  `  (IG i³  265.ii.51;Apollonius Aphrodisiensis  (FGrHist 740)  fr. 4  (perhaps  C 3))  or `  (I.Mylasa 401.8  (C 2­C1)).
# ----
# Hydisos  was  a  member  of  the  Delian  League,  but  is  registered  only  twice,  in  448/7  (IG i³  264.iii.21,  restored: `[~]) and 447/6  (IG i³  265.ii.51,  restored: `[~]),  paying  a  phoros  of 1  tal.
# ----
# At  the  site  of  Hydisos  there  are  remains  of  city  walls  and towers,  probably  of  early  Hellenistic  date  (L.  Robert  ( 1935) 339­40).
# ----
# 890.
# ----
# (Hymisseis) Map 61,  unlocated,  but  possibly  situat- ed  between  Amyzon  (no.
# ----
# 874)  and  Mylasa  (no.
# ----
# 913)  (Pontani ( 1997)  7;  cf.
# ----
# L.  Robert  ( 1955)  226).
# ----
# Type:  C: .
# ----
# A  toponym  is not  attested.
# ----
# The  city-ethnic  is  `µ  (IG i³  262.iv.19; restored:  [h ]µ~) or `µ  (IG i³  71.ii.143;  IG xii suppl.
# ----
# 127.58  (C 3)).
# ----
# The  collective  use  of  the  city-ethnic  is attested  externally  in  the  tribute  lists  and  in  the  assessment decree  of 425/4  (IG i³  71.ii.143).
# ----
# The  Hymisseis  were  members  of  the  Delian  League.
# ----
# They are  recorded  three  times  in  the  lists  from  451/0  (IG i³ 262.iv.19)  to  447/6  (IG i³  265.ii.50),  paying  a  phoros  of 1,200 dr.
# ----
# In  the  assessment  decree  of 425/4  they  form  a  syntely  with the  Edrieis  (no.
# ----
# 892)  and  Kyromeis,  and  the  three  together are  assessed  at  6  tal.  (IG i³  71.ii.143­44).
# ----
# A  Hymesseus  is recorded  in a C 3  list  of  proxenoi  from  Eresos  (no.
# ----
# 796)  (IG xii suppl.
# ----
# 127.58).
# ----
# 891.
# ----
